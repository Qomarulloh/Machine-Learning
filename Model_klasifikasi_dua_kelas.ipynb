# %% [markdown]
# <a href="https://colab.research.google.com/github/Qomarulloh/Machine-Learning/blob/main/Model_klasifikasi_dua_kelas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df = pd.read_csv('citrus.csv')
df.head(10000)
# Out:
#             name  diameter  weight  red  green  blue
# 0         orange      2.96   86.76  172     85     2
# 1         orange      3.91   88.05  166     78     3
# 2         orange      4.42   95.17  156     81     2
# 3         orange      4.47   95.60  163     81     4
# 4         orange      4.48   95.76  161     72     9
# ...          ...       ...     ...  ...    ...   ...
# 9995  grapefruit     15.35  253.89  149     77    20
# 9996  grapefruit     15.41  254.67  148     68     7
# 9997  grapefruit     15.59  256.50  168     82    20
# 9998  grapefruit     15.92  260.14  142     72    11
# 9999  grapefruit     16.45  261.51  152     74     2
#
# [10000 rows x 6 columns]

# %%
df.name[df.name == 'orange'] = 0
df.name[df.name == 'grapefruit'] = 1
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df.head(10000)
# Out:
#      name  diameter  weight  red  green  blue
# 0       0      2.96   86.76  172     85     2
# 1       0      3.91   88.05  166     78     3
# 2       0      4.42   95.17  156     81     2
# 3       0      4.47   95.60  163     81     4
# 4       0      4.48   95.76  161     72     9
# ...   ...       ...     ...  ...    ...   ...
# 9995    1     15.35  253.89  149     77    20
# 9996    1     15.41  254.67  148     68     7
# 9997    1     15.59  256.50  168     82    20
# 9998    1     15.92  260.14  142     72    11
# 9999    1     16.45  261.51  152     74     2
#
# [10000 rows x 6 columns]

# %%
dataset = df.values
dataset
# Out:
# array([[0, 2.96, 86.76, 172, 85, 2],
#        [0, 3.91, 88.05, 166, 78, 3],
#        [0, 4.42, 95.17, 156, 81, 2],
#        ...,
#        [1, 15.59, 256.5, 168, 82, 20],
#        [1, 15.92, 260.14, 142, 72, 11],
#        [1, 16.45, 261.51, 152, 74, 2]], dtype=object)

# %%
X = dataset[:,1:6]
y = dataset[:,0]

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
X_scale = min_max_scaler.fit_transform(X)
X_scale
# Out:
# array([[0.        , 0.        , 0.74025974, 0.63529412, 0.        ],
#        [0.07042254, 0.00738197, 0.66233766, 0.55294118, 0.01851852],
#        [0.10822832, 0.04812589, 0.53246753, 0.58823529, 0.        ],
#        ...,
#        [0.93624907, 0.97133047, 0.68831169, 0.6       , 0.33333333],
#        [0.96071164, 0.99216023, 0.35064935, 0.48235294, 0.16666667],
#        [1.        , 1.        , 0.48051948, 0.50588235, 0.        ]])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scale, y, test_size=0.3)

# %%
import numpy as np

y_train = y_train.astype(np.float32)
y_test = y_test.astype(np.float32)

# %%
from keras.models import Sequential
from keras.layers import Dense

# %%
model = Sequential([
                    Dense(32, activation='relu', input_shape=(5,)),
                    Dense(32, activation='relu'),
                    Dense(1, activation='sigmoid')
])

# %%
model.compile(optimizer='sgd',
              loss='binary_crossentropy',
              metrics=['accuracy'])

# %%
model.fit(X_train, y_train, epochs=100)
# Out:
# Epoch 1/100
# 219/219 [==============================] - 2s 3ms/step - loss: 0.7010 - accuracy: 0.4986
# Epoch 2/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.6786 - accuracy: 0.7294
# Epoch 3/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.6561 - accuracy: 0.8787
# Epoch 4/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.6233 - accuracy: 0.9040
# Epoch 5/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.5719 - accuracy: 0.9071
# Epoch 6/100
# 219/219 [==============================] - 1s 3ms/step - loss: 0.4984 - accuracy: 0.9196
# Epoch 7/100
# 219/219 [==============================] - 1s 2ms/step - loss: 0.4107 - accuracy: 0.9244
# Epoch 8/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.3291 - accuracy: 0.9271
# Epoch 9/100
# 219/219 [==============================] - 0s 2ms/step - loss: 0.2701 - accuracy: 0.9281
# Epoch 10/100
# ...

# %%
model.evaluate(X_test, y_test)
# Out:
# 94/94 [==============================] - 0s 2ms/step - loss: 0.2001 - accuracy: 0.9190
# [0.20010091364383698, 0.9190000295639038]
